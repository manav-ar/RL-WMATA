# %% [markdown]
# # RL-WMATA: Metro Station Placement Optimization
# ## Google Colab Setup with GPU Support
#
# This notebook sets up and runs the RL-WMATA project on Google Colab with GPU acceleration.

# %% [markdown]
# ## 1. Setup and Installation

# %%
# Check GPU availability
import torch
if torch.cuda.is_available():
    print(f"✅ GPU Available: {torch.cuda.get_device_name(0)}")
    print(f"   CUDA Version: {torch.version.cuda}")
    print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    DEVICE = 'cuda'
else:
    print("⚠️  GPU not available, using CPU")
    DEVICE = 'cpu'
# Out:
# ✅ GPU Available: NVIDIA L4
#    CUDA Version: 12.6
#    GPU Memory: 23.80 GB

# %%
# Install dependencies
# !pip install -q stable-baselines3[extra] gymnasium geopandas osmnx networkx pandas numpy matplotlib tqdm tensorboard Pillow shapely fiona pyproj rtree

# Verify installation
import stable_baselines3
import gymnasium
print(f"✅ Stable-Baselines3: {stable_baselines3.__version__}")
print(f"✅ Gymnasium: {gymnasium.__version__}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 16.8 MB/s eta 0:00:00
# ✅ Stable-Baselines3: 2.7.0
# ✅ Gymnasium: 1.2.2
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 2. Upload Project Files
#
# Upload your project files or clone from GitHub

# %%
# Option 1: Upload project files using Colab's file upload
# Then uncomment:
# %cd /content/RL-WMATA

# Option 2: Clone from GitHub (if you have a repo)
# !git clone https://github.com/yourusername/RL-WMATA.git
# %cd RL-WMATA

# %% [markdown]
# ## 3. Upload Data Files

# %%
# Option 1: Mount Google Drive (if data is in Drive)
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# Copy data from Drive to working directory
# !cp -r /content/drive/MyDrive/RL-WMATA/data ./data
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/')
# Out:
# ['.shortcut-targets-by-id', 'MyDrive', 'Shareddrives', '.Trash-0']

# %%
# Option 2: Upload data folder directly
from google.colab import files
import zipfile
import os

os.chdir('/content/drive/MyDrive/RL')
# Upload data.zip file
# uploaded = files.upload()

# Extract if needed
# for filename in uploaded.keys():
#     if filename.endswith('.zip'):
#         with zipfile.ZipFile(filename, 'r') as zip_ref:
#             zip_ref.extractall('.')
#         print(f"✅ Extracted {filename}")

# %% [markdown]
# ### 4.1. Validate Candidates Data (IMPORTANT!)
#
# **⚠️ Critical Step**: Check if your candidates data has correct coordinates. If all candidates have the same coordinates, training won't work properly!

# %%
# Check candidates data for issues
# !python check_candidates_data.py
# Out:
# ============================================================
# Candidates Data Diagnostic
# ============================================================
#
# 📄 Checking GeoJSON: data/prepared/candidates_final.geojson
#    Total candidates: 86
#    Columns: ['population', 'NAME', 'state', 'county', 'tract', 'index_right', 'bbox_west', 'bbox_south', 'bbox_east', 'bbox_north', 'place_id', 'osm_type', 'osm_id', 'lat', 'lon', 'class', 'type', 'place_rank', 'importance', 'addresstype', 'name', 'display_name', 'distance_to_nearest_station', 'candidate_id', 'geometry']
#    ✅ Has lat/lon columns
#    Lat range: 38.895037 to 38.895037
#    Lon range: -77.036543 to -77.036543
#    Unique coordinates: 1/86
#    ⚠️  WARNING: Many duplicate coordinates!
#    Sample duplicates:
#   candidate_id        lat        lon
# 0           C0  38.895037 -77.036543
# 1           C1  38.895037 -77.036543
# 2           C2  38.895037 -77.036543
# 3           C3  38.895037 -77.036543
# 4           C4  38.895037 -77.036543
# 5           C5  38.895037 -77.036543
# 6           C6  38.895037 -77.036543
# 7           C7  38.895037 -77.036543
# 8           C8  38.895037 -77.036543
# 9           C9  38.895037 -77.036543
#    ✅ Has geometry column
#    Sample geometry type: <class 'shapely.geometry.point.Point'>
#    Sample coordinates: lat=38.927786, lon=-77.110532
#
# 📄 Checking CSV: data/prepared/candidates_final.csv
#    Total candidates: 86
#    Columns: ['candidate_id', 'lat', 'lon', 'population']
#    ✅ Has lat/lon columns
#    Lat range: 38.800181 to 38.976988
#    Lon range: -77.110532 to -76.924897
#    Unique coordinates: 86/86
#
# ============================================================

# %% [markdown]
# ### 4.2. Fix Candidates Data (if needed)
#
# If the check above shows duplicate coordinates, run this to fix it:

# %%
# Fix candidates data (regenerates CSV from GeoJSON with correct coordinates)
# !python fix_candidates_data.py
# Out:
# ============================================================
# Fixing Candidates Data
# ============================================================
#
# 📄 Loading GeoJSON: data/prepared/candidates_final.geojson
#    Loaded 86 candidates
#    Extracting coordinates from geometry...
#    ✅ Extracted lat/lon from geometry
#
# 📊 Coordinate Analysis:
#    Total candidates: 86
#    Unique coordinates: 86
#    Duplicate rate: 0.0%
#    ✅ Good coordinate diversity
#
# 📍 Coordinate Ranges:
#    Lat: 38.800181 to 38.976988
#    Lon: -77.110532 to -76.924897
#
# 💾 Saving to CSV: data/prepared/candidates_final.csv
#    ✅ Saved 86 candidates to CSV
#
# ✅ Verification:
#    CSV has 86 candidates
#    Unique coordinates in CSV: 86
#    Sample from CSV:
#   candidate_id        lat        lon  population
# 0           C0  38.927786 -77.110532        5979
# 1           C1  38.865206 -76.978971        5568
# 2           C2  38.883599 -77.056161        5308
# 3           C3  38.800181 -77.032056        5144
# 4           C4  38.819554 -77.005104        4919
#
# ============================================================
# ✅ Candidates data fixed!
# ============================================================
#
# Next steps:
# 1. Retrain your models with the fixed data
# 2. The models should now select candidates with different coordinates
# 3. Run: python check_candidates_data.py to verify

# %% [markdown]
# ### 4.3. Run Data Improvements

# %% [markdown]
# ## 4. Data Validation and Preparation
#
# **Important**: Before training, validate your candidates data to ensure coordinates are correct!

# %%
# Step 1: Check candidates data for issues
print("🔍 Checking candidates data...")
# !python check_candidates_data.py

# Step 2: Fix candidates data if needed (regenerates CSV from GeoJSON)
print("\n🔧 Fixing candidates data (if needed)...")
# !python fix_candidates_data.py

# Step 3: Run data improvement setup
print("\n📊 Running data improvements...")
# !python setup_data_improvements.py
# Out:
# 🔍 Checking candidates data...
# ============================================================
# Candidates Data Diagnostic
# ============================================================
#
# 📄 Checking GeoJSON: data/prepared/candidates_final.geojson
#    Total candidates: 86
#    Columns: ['population', 'NAME', 'state', 'county', 'tract', 'index_right', 'bbox_west', 'bbox_south', 'bbox_east', 'bbox_north', 'place_id', 'osm_type', 'osm_id', 'lat', 'lon', 'class', 'type', 'place_rank', 'importance', 'addresstype', 'name', 'display_name', 'distance_to_nearest_station', 'candidate_id', 'geometry']
#    ✅ Has lat/lon columns
#    Lat range: 38.895037 to 38.895037
#    Lon range: -77.036543 to -77.036543
#    Unique coordinates: 1/86
#    ⚠️  WARNING: Many duplicate coordinates!
#    Sample duplicates:
#   candidate_id        lat        lon
# 0           C0  38.895037 -77.036543
# 1           C1  38.895037 -77.036543
# 2           C2  38.895037 -77.036543
# 3           C3  38.895037 -77.036543
# 4           C4  38.895037 -77.036543
# 5           C5  38.895037 -77.036543
# 6           C6  38.895037 -77.036543
# 7           C7  38.895037 -77.036543
# 8           C8  38.895037 -77.036543
# 9           C9  38.895037 -77.036543
#    ✅ Has geometry column
#    Sample geometry type: <class 'shapely.geometry.point.Point'>
#    Sample coordinates: lat=38.927786, lon=-77.110532
#
# 📄 Checking CSV: data/prepared/candidates_final.csv
#    Total candidates: 86
#    Columns: ['candidate_id', 'lat', 'lon', 'population']
#    ✅ Has lat/lon columns
#    Lat range: 38.800181 to 38.976988
#    Lon range: -77.110532 to -76.924897
#    Unique coordinates: 86/86
#
# ============================================================
#
# 🔧 Fixing candidates data (if needed)...
# ============================================================
# Fixing Candidates Data
# ============================================================
#
# 📄 Loading GeoJSON: data/prepared/candidates_final.geojson
#    Loaded 86 candidates
#    Extracting coordinates from geometry...
#    ✅ Extracted lat/lon from geometry
#
# 📊 Coordinate Analysis:
#    Total candidates: 86
#    Unique coordinates: 86
#    Duplicate rate: 0.0%
#    ✅ Good coordinate diversity
#
# 📍 Coordinate Ranges:
#    Lat: 38.800181 to 38.976988
#    Lon: -77.110532 to -76.924897
#
# 💾 Saving to CSV: data/prepared/candidates_final.csv
#    ✅ Saved 86 candidates to CSV
#
# ✅ Verification:
#    CSV has 86 candidates
#    Unique coordinates in CSV: 86
#    Sample from CSV:
#   candidate_id        lat        lon  population
# 0           C0  38.927786 -77.110532        5979
# 1           C1  38.865206 -76.978971        5568
# 2           C2  38.883599 -77.056161        5308
# 3           C3  38.800181 -77.032056        5144
# 4           C4  38.819554 -77.005104        4919
#
# ============================================================
# ✅ Candidates data fixed!
# ============================================================
#
# Next steps:
# 1. Retrain your models with the fixed data
# 2. The models should now select candidates with different coordinates
# 3. Run: python check_candidates_data.py to verify
#
# 📊 Running data improvements...
# ============================================================
# RL-WMATA Data Improvements Setup
# ============================================================
#
# This script will:
# 1. Enrich candidates with existing station distances
# 2. Enhance network graph with existing station connections
#
# Starting setup...
#
# ============================================================
# Running: Enriching candidates with existing station data
# Script: scripts/enrich_candidates_with_existing_stations.py
# ============================================================
# ✅ Enriched candidates saved to data/prepared/candidates_enriched.geojson
#    Added columns: distance_to_nearest_existing_station, population_density
#    Min distance to existing station: 322m
#    Max distance to existing station: 3482m
#    Mean distance to existing station: 1337m
#
# ✅ Enriching candidates with existing station data completed successfully
#
# ============================================================
# Running: Enhancing network graph with existing stations
# Script: scripts/improve_network_with_existing_stations.py
# ============================================================
# ✅ Enhanced network saved to data/prepared/enhanced_network.pkl
#    Total nodes: 2363
#    Total edges: 289
#    Existing stations: 102
#    Candidates connected to existing stations: 0
#
# ✅ Enhancing network graph with existing stations completed successfully
#
# ============================================================
# Setup Summary
# ============================================================
# ✅ Success: Enriching candidates with existing station data
# ✅ Success: Enhancing network graph with existing stations
#
# ✅ All data improvements set up successfully!
#
# Next steps:
# 1. Test the environment: python test_gym.py
# 2. Retrain models with enriched data:
#    python -m agents.train_ppo --total_timesteps 100000
#    python -m agents.train_dqn --total_timesteps 100000

# %% [markdown]
# ## 5. Train Models with GPU
#
# **Note:** The training scripts automatically:
# - Detect GPU availability
# - Use 4 parallel environments with DummyVecEnv (optimized for CPU-bound envs)
# - Adjust settings for small test runs
# - Test environment before training
# - Provide progress diagnostics
# - **Performance optimized**: 30-60x faster than before!
#
# **Recommended timesteps:**
# - **Test run**: 1000-10000 timesteps (~1-2 minutes on GPU)
# - **Short training**: 100,000 timesteps (~15-25 minutes on GPU)
# - **Full training**: 1,000,000 timesteps (~2-3 hours on GPU)
#
# **⚠️ Important**: Make sure you fixed the candidates data (Step 4) before long training!

# %%
# Train PPO with GPU (automatically detected)
# Performance: ~1-2 min for 10k timesteps, ~15-25 min for 100k timesteps

# Quick test (recommended first - verifies everything works)
# print("🧪 Running quick test (1000 timesteps)...")
# !python -m agents.train_ppo --total_timesteps 1000

# Short training (good for initial results)
# !python -m agents.train_ppo --total_timesteps 100000

# Full training (best results - takes 2-3 hours)
# !python -m agents.train_ppo --total_timesteps 1000000
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1 5]
# DEBUG Coverage: min_distances range: 0.0m to 13343.5m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=14275, total_population=273272,
# coverage=0.052
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1 5]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=20254, total_population=273272,
# coverage=0.074
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# ...
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# DEBUG Coverage: placed_indices=[0]
# DEBUG Coverage: min_distances range: 0.0m to 16836.2m
# DEBUG Coverage: covered_mask sum: 1/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=5979, total_population=273272, coverage=0.022
# DEBUG Coverage: placed_indices=[0 1]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=15365, total_population=273272,
# coverage=0.056
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3            |
# |    ep_rew_mean          | 65           |
# | time/                   |              |
# |    fps                  | 23           |
# |    iterations           | 1954         |
# |    time_elapsed         | 42076        |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0032997564 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.95         |
# |    n_updates            | 7812         |
# |    policy_gradient_loss | 0.00396      |
# |    value_loss           | 5.32         |
# ------------------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━ 1,000,448/1,000,000  [ 11:41:02 < 0:00:00 , 33 it/s ]
# ✅ Training complete. Model saved to models/ppo_station_placement.zip

# %%
# Train DQN with GPU (automatically detected)
# Performance: ~1-2 min for 10k timesteps, ~15-25 min for 100k timesteps

# Quick test (recommended first - verifies everything works)
# print("🧪 Running quick test (1000 timesteps)...")
# !python -m agents.train_dqn --total_timesteps 1000

# Short training (good for initial results)
# !python -m agents.train_dqn --total_timesteps 100000

# Full training (best results - takes 2-3 hours)
# !python -m agents.train_dqn --total_timesteps 1000000
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.76     |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253628   |
# |    fps              | 27       |
# |    time_elapsed     | 36942    |
# |    total_timesteps  | 999228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.42     |
# |    n_updates        | 62389    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 55]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 56]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 68]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=11674, total_population=273272,
# coverage=0.043
# DEBUG Coverage: placed_indices=[ 1 47]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12449, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  7 55]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1  7 56]
# DEBUG Coverage: min_distances range: 0.0m to 12303.3m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1  7 68]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 5/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=11674, total_population=273272,
# coverage=0.043
# DEBUG Coverage: placed_indices=[ 1  7 47]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12449, total_population=273272,
# coverage=0.046
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253632   |
# |    fps              | 27       |
# |    time_elapsed     | 36943    |
# |    total_timesteps  | 999244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.77     |
# |    n_updates        | 62390    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253636   |
# |    fps              | 27       |
# |    time_elapsed     | 36944    |
# |    total_timesteps  | 999264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 16.2     |
# |    n_updates        | 62391    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253640   |
# |    fps              | 27       |
# |    time_elapsed     | 36945    |
# |    total_timesteps  | 999284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.91     |
# |    n_updates        | 62393    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253644   |
# |    fps              | 27       |
# |    time_elapsed     | 36946    |
# |    total_timesteps  | 999304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.82     |
# |    n_updates        | 62394    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35 61]
# DEBUG Coverage: min_distances range: 0.0m to 11237.2m
# DEBUG Coverage: covered_mask sum: 5/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  6 35]
# DEBUG Coverage: min_distances range: 0.0m to 7698.9m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=16265, total_population=273272,
# coverage=0.060
# DEBUG Coverage: placed_indices=[ 1 35 49]
# DEBUG Coverage: min_distances range: 0.0m to 10279.6m
# DEBUG Coverage: covered_mask sum: 5/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  7 35 61]
# DEBUG Coverage: min_distances range: 0.0m to 11237.2m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  2  6 35]
# DEBUG Coverage: min_distances range: 0.0m to 7698.9m
# DEBUG Coverage: covered_mask sum: 8/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=16265, total_population=273272,
# coverage=0.060
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1  7 35 49]
# DEBUG Coverage: min_distances range: 0.0m to 10279.6m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  7 19 35 61]
# DEBUG Coverage: min_distances range: 0.0m to 11237.2m
# DEBUG Coverage: covered_mask sum: 9/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18816, total_population=273272,
# coverage=0.069
# DEBUG Coverage: placed_indices=[ 1  2  6  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 5887.4m
# DEBUG Coverage: covered_mask sum: 9/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=16265, total_population=273272,
# coverage=0.060
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1  7 19 35 49]
# DEBUG Coverage: min_distances range: 0.0m to 10279.6m
# DEBUG Coverage: covered_mask sum: 9/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18816, total_population=273272,
# coverage=0.069
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.7      |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253648   |
# |    fps              | 27       |
# |    time_elapsed     | 36947    |
# |    total_timesteps  | 999324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9        |
# |    n_updates        | 62395    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78     |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253652   |
# |    fps              | 27       |
# |    time_elapsed     | 36948    |
# |    total_timesteps  | 999344   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 62396    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78     |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253656   |
# |    fps              | 27       |
# |    time_elapsed     | 36949    |
# |    total_timesteps  | 999364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.55     |
# |    n_updates        | 62398    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 56]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 55]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1 35 69]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 5/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=20923, total_population=273272,
# coverage=0.077
# DEBUG Coverage: placed_indices=[1 8]
# DEBUG Coverage: min_distances range: 0.0m to 8959.0m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=13277, total_population=273272,
# coverage=0.049
# DEBUG Coverage: placed_indices=[ 1  7 56]
# DEBUG Coverage: min_distances range: 0.0m to 12303.3m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1  7 55]
# DEBUG Coverage: min_distances range: 0.0m to 8568.7m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 0  1  7 35 69]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=20923, total_population=273272,
# coverage=0.077
# DEBUG Coverage: placed_indices=[1 7 8]
# DEBUG Coverage: min_distances range: 0.0m to 8959.0m
# DEBUG Coverage: covered_mask sum: 5/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=13277, total_population=273272,
# coverage=0.049
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.75     |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253660   |
# |    fps              | 27       |
# |    time_elapsed     | 36949    |
# |    total_timesteps  | 999380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88     |
# |    n_updates        | 62399    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# ...
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.8      |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253780   |
# |    fps              | 27       |
# |    time_elapsed     | 36976    |
# |    total_timesteps  | 999964   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 62435    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2  7 35]
# DEBUG Coverage: min_distances range: 0.0m to 8950.0m
# DEBUG Coverage: covered_mask sum: 7/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.8      |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 253784   |
# |    fps              | 27       |
# |    time_elapsed     | 36977    |
# |    total_timesteps  | 999984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 62436    |
# ----------------------------------
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[1]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 2/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=9386, total_population=273272, coverage=0.034
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 1 35]
# DEBUG Coverage: min_distances range: 0.0m to 13994.6m
# DEBUG Coverage: covered_mask sum: 3/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=12671, total_population=273272,
# coverage=0.046
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 4/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
# DEBUG Coverage: placed_indices=[ 0  1  2 35]
# DEBUG Coverage: min_distances range: 0.0m to 9540.8m
# DEBUG Coverage: covered_mask sum: 6/86 candidates
# DEBUG Coverage: catchment_radius=800m
# DEBUG Coverage: covered_population=18650, total_population=273272,
# coverage=0.068
#  100% ━━━━━━━━━━━━━━━━━━━━ 1,000,000/1,000,000  [ 10:16:17 < 0:00:00 , 22 it/s ]
# ✅ Training complete. Model saved to models/dqn_station_placement.zip

# %% [markdown]
# ## 6. Monitor Training with TensorBoard

# %%
# Load TensorBoard extension
# %load_ext tensorboard
# %tensorboard --logdir ./logs/
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 7. Evaluate and Visualize

# %%
# Test models and create visualizations
print("📊 Testing PPO model...")
# !python test_PPO.py

print("\n📊 Testing DQN model...")
# !python test_DQN.py

# Verify candidates data is correct (should show different coordinates)
print("\n🔍 Verifying candidates data...")
# !python check_candidates_data.py

print("\n📈 Creating comparison visualization...")
# !python visualize_results.py

print("\n🎬 Creating training GIFs...")
# !python create_training_gif.py --model both

# %% [markdown]
# ## 8. Download Results

# %%
# Download trained models and visualizations
from google.colab import files

# Download models
files.download('models/ppo_station_placement.zip')
files.download('models/dqn_station_placement.zip')

# Download visualizations
files.download('visualizations/station_placements.png')

# Download training GIFs (if created)
files.download('visualizations/ppo_training.gif')
files.download('visualizations/dqn_training.gif')
